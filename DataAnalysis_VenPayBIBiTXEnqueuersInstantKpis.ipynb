# %% [markdown]
# # N<span style="color: #99ffff;">-</span>AND ITALIA <span style="color: #99ffff;">-</span> ADEBANJI ADELOWO

# %% [markdown]
# ## Working with the DataBase: VENPAYBI

# %% [markdown]
# ### The Table dbo.BiTXEnqueuersInstantKpis

# %%
import os
import sys
import warnings
warnings.filterwarnings('ignore')

# %%
import pyodbc
pyodbc.drivers()
# Out:
# ['SQL Server',
#  'Microsoft Access Driver (*.mdb, *.accdb)',
#  'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)',
#  'Microsoft Access Text Driver (*.txt, *.csv)',
#  'SQL Server Native Client RDA 11.0',
#  'ODBC Driver 17 for SQL Server']

# %% [markdown]
# First establish connection to the database using python

# %%
import pandas as pd
import matplotlib.pyplot as plt


# server = 'localhost\sqlexpress' # for a named instance
# server = 'myserver,port' # to specify an alternate port
server = 'vpay-asdmi.public.21203d2a181c.database.windows.net,3342' 
database = 'VENPAY-BI' 
username = 'nandaa' 
password = 'Timileyin1998'  

engine = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = engine.cursor()

# %%
query = """SELECT *
          FROM [VENPAY-BI].[dbo].[BiTXEnqueuers] B INNER JOIN [VENPAY-BI].[dbo].[BiTXEnqueuersInstantKpis] BE 
            ON B.PK_BiTXEnqueuerId = BE.FK_BiTXEnqueuerId
 """

df_bitx3 = pd.read_sql(query, engine)
df_bitx3
# Out:
#         PK_BiTXEnqueuerId Hostname EnqueuerName                QueueName  \
# 0                       2   conn01   BiTXSQSEn1            Demobitx_Test
# 1                       3   conn01   BiTXSQSEn1              VegaSQS_DAI
# 2                       4   conn01   BiTXSQSEn1              VegaSQS_EOS
# 3                       5   conn01   BiTXSQSEn1  VegaSQS_GESAIVSItalia_0
# 4                       6   conn01   BiTXSQSEn1         VegaSQS_LIOMATIC
# ...                   ...      ...          ...                      ...
# 421622                  8   conn01   BiTXSQSEn2      VegaSQS_IVSItalia_0
# 421623                  9   conn01   BiTXSQSEn2      VegaSQS_IVSItalia_1
# 421624                 10   conn01   BiTXSQSEn2      VegaSQS_IVSItalia_2
# 421625                 11   conn01   BiTXSQSEn2      VegaSQS_IVSItalia_3
# 421626                  2   conn01   BiTXSQSEn1            Demobitx_Test
#
#                    LastKpi  PK_BiTXEnqueuersInstantKpisId  FK_BiTXEnqueuerId  \
# 0      2023-07-18 10:45:00                              1                  2
# 1      2023-07-18 10:45:00                              3                  3
# 2      2023-07-18 10:45:00                              4                  4
# 3      2023-01-24 12:50:00                              5                  5
# 4      2023-07-18 10:45:00                              6                  6
# ...                    ...                            ...                ...
# 421622 2023-07-18 10:40:00                         268751                  8
# 421623 2023-07-18 10:40:00                         268752                  9
# 421624 2023-07-18 10:40:00                         268753                 10
# 421625 2023-07-18 10:40:00                         268754                 11
# 421626 2023-07-18 10:45:00                         268755                  2
#
#              ReferenceDate  RetrieveCompletedCounter  RetrieveErrorsCounter  \
# 0      2022-12-19 08:05:00                         0                      0
# 1      2022-12-19 08:05:00                       537                      0
# 2      2022-12-19 08:05:00                         2                      0
# 3      2022-12-19 08:05:00                         0                      0
# 4      2022-12-19 08:05:00                       455                      0
# ...                    ...                       ...                    ...
# 421622 2023-04-09 12:45:00                       151                      0
# 421623 2023-04-09 12:45:00                       244                      0
# 421624 2023-04-09 12:45:00                       198                      0
# 421625 2023-04-09 12:45:00                       213                      0
# 421626 2023-04-09 12:50:00                         0                      0
#
#         FilterCompletedCounter  FilterErrorsCounter  EnqueueCompletedCounter  \
# 0                            0                    0                        0
# 1                          137                    0                      400
# 2                            0                    0                        2
# 3                            0                    0                        0
# 4                           90                    0                      365
# ...                        ...                  ...                      ...
# 421622                      50                    0                      101
# 421623                      76                    0                      168
# 421624                      63                    0                      135
# 421625                      47                    0                      166
# 421626                       0                    0                        0
#
#         EnqueueErrorsCounter  IsRetrieveError  IsFilterError  IsEnqueueError  \
# 0                          0            False          False           False
# 1                          0            False          False           False
# 2                          0            False          False           False
# 3                          0            False          False           False
# 4                          0            False          False           False
# ...                      ...              ...            ...             ...
# 421622                     0            False          False           False
# 421623                     0            False          False           False
# 421624                     0            False          False           False
# 421625                     0            False          False           False
# 421626                     0            False          False           False
#
#         LastEventId     LastEventInsertDate
# 0         873330348 2022-12-19 07:56:16.397
# 1         873335233 2022-12-19 08:04:49.840
# 2         873334473 2022-12-19 08:03:59.713
# 3                 0                     NaT
# 4         873335222 2022-12-19 08:04:49.250
# ...             ...                     ...
# 421622    929847891 2023-04-09 12:44:13.527
# 421623    929847969 2023-04-09 12:44:33.913
# 421624    929848042 2023-04-09 12:44:56.393
# 421625    929847973 2023-04-09 12:44:34.753
# 421626    929768891 2023-04-09 08:17:51.697
#
# [421627 rows x 19 columns]

# %%
df_bitx3.describe()
# Out:
#        PK_BiTXEnqueuerId  PK_BiTXEnqueuersInstantKpisId  FK_BiTXEnqueuerId  \
# count      421627.000000                  421627.000000      421627.000000
# mean            8.312924                  238900.414800           8.312924
# std             4.040677                  135686.124618           4.040677
# min             2.000000                       1.000000           2.000000
# 25%             4.000000                  121102.000000           4.000000
# 50%             9.000000                  238896.000000           9.000000
# 75%            12.000000                  356077.500000          12.000000
# max            14.000000                  473261.000000          14.000000
#
#        RetrieveCompletedCounter  RetrieveErrorsCounter  \
# count             421627.000000          421627.000000
# mean                 171.395454               0.000225
# std                  214.124692               0.015476
# min                    0.000000               0.000000
# 25%                    2.000000               0.000000
# 50%                  122.000000               0.000000
# 75%                  262.000000               0.000000
# max                 4500.000000               2.000000
#
#        FilterCompletedCounter  FilterErrorsCounter  EnqueueCompletedCounter  \
# count           421627.000000        421627.000000            421627.000000
# mean                41.849059             0.008183               116.658905
# std                 63.173154             0.255583               141.012156
# min                  0.000000             0.000000                 0.000000
# 25%                  0.000000             0.000000                 1.000000
# 50%                 18.000000             0.000000                86.000000
# 75%                 62.000000             0.000000               192.000000
# max               1868.000000            10.000000              3528.000000
#
#        EnqueueErrorsCounter   LastEventId
# count         421627.000000  4.216270e+05
# mean               0.246398  9.037416e+08
# std                2.164484  1.367979e+08
# min                0.000000  0.000000e+00
# 25%                0.000000  8.978719e+08
# 50%                0.000000  9.234159e+08
# 75%                0.000000  9.458034e+08
# max               20.000000  9.847782e+08

# %%
query = """ SELECT FK_BiTXEnqueuerId, 
                COUNT(*) AS Count1,
                SUM(EnqueueCompletedCounter) AS Count2
        FROM [VENPAY-BI].[dbo].[BiTXEnqueuers] B INNER JOIN [VENPAY-BI].[dbo].[BiTXEnqueuersInstantKpis] BE 
            ON B.PK_BiTXEnqueuerId = BE.FK_BiTXEnqueuerId
        GROUP BY FK_BiTXEnqueuerId, EnqueuerName
 """

df_bitx3 = pd.read_sql(query, engine)
df_bitx3
# Out:
#     FK_BiTXEnqueuerId  Count1    Count2
# 0                  13   41754     82332
# 1                   9   32824   6709300
# 2                   2   39222     10878
# 3                   6   39222   4256465
# 4                  10   32824   6104517
# 5                  11   32824   7156172
# 6                   4   39222     58031
# 7                   3   39222  10134897
# 8                   5    8181         0
# 9                  12   41754   6199878
# 10                  8   32824   6528261
# 11                 14   41754   1945813
